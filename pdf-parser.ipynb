# %%
# open document.pdf and parse all of its text

# Import the PyPDF2 library
import PyPDF2 as pypdf2

# Open the PDF file in read-binary mode
with open('document.pdf', 'rb') as file:
    # Create a PDF object
    pdf = pypdf2.PdfFileReader(file)

    # Initialize an empty list to store the text
    text = []

    # Iterate over the pages of the PDF
    for page in range(pdf.getNumPages()):
        # Extract the text from the page
        page_text = pdf.getPage(page).extractText()

        # Append the text to the list
        text.append(page_text)

# Print the extracted text
print(text)
# Out:
# [' \n \n \nHans Wener Weil  \nBruchweg 7  \n35410  Hungen   \n ', ' \n Skizze zu IHRE R Photovoltaikanlage  \n \n \n \n \n \n \n \n \n \n \nEckdaten zur geplanten Photovoltaikanlage  \nVorna me Name  Hans Wener Weil  \nLeistung der Anlage  9,2 4 kWp  \nBesonderheiten  Zur Ausführung des Auftrags können \nZusatzkosten z.B. im Bereich Absturz-\nschutz notwendig werden. Dies wird \njedoch vor Installation bekannt gegeben.  ', 'Kunde Hans Wener Weil PV-Anlage mit Stromspeicher \nDatum \nStrombedarf ca. \nStrompreis inkl. MwSt. \nStrompreissteigerung \nInbetriebnahme (voraussichtlich)\nEEG Vergütung (voraussichtlich)\nEEG Vergütungszeitraum \nVerminderte EEG Umlage \nLeistung der PV-Anlage \nErtrag der Anlage \nKapazität des Stromspeichers \nInvestitionskosten \nErsparnis der Stromkosten im 1. Betriebsjahr   70% \nEinnahme durch Stromverkauf pro Betriebsjahr   30% \nJahresergebnis: \nBeispiel: 2.017,86 €      \nWertschöpfung innerhalb \ndes Vergütungszeitraums*: 66.474,36 €  Ihre persönliche Energiewende in der Übersicht \n7.392 kWh 8,20 ct/kWh 39,00 ct/kWh \nIhr Jahresergebnis aus der Energieerzeugung der PV- Anlage: 31.10.2022 \n8.536 kWh \n4% pro Jahr \n20,6 Jahre \n9,24 kWp \n38.872,54 €Juni 2023 \n0,00 ct/kWh \n10,0 kWh \n2.017,86 €            \n*Abzüglich eventuell anfallender Kosten für Zählermiete u nd Messdienstleistung des zuständigen Energieversorgers . Die hier gemachten Angaben dienen nur als Veranschaulichu ng. Der \ntatsächliche Strombedarf und die Strombezugskosten sowie der Umfang des Eigenverbrauchs, das Wetter und andere Fakto ren haben naturgemäß Einfluss auf das Ergebnis und den Nutze n. Die \nAngaben sind daher ohne Gewähr! 181,88 €               \n2.199,74 €            5.174 kWh x Strompreis \n2.218 kWh x EEG-Vergütung \n38.872,54 €    Investitionskosten \ninkl. MwSt: \nErsparnis der \nStrombezugskosten \nim 1. Betriebsjahr \nabzgl. evtl. EEG-Umlage: \nWertschöpfung \nim 1. Betriebsjahr*: 5,7% Verzinsung des \neingesetzten Kapitals \nim 1. Betriebsjahr: \nEinnahmen durch \nStromverkauf \nim 1. Betriebsjahr: \n2.199,74 €      181,88 €       39% \n61% Energieerzeugung: \nEigenverbrauch / Netzeinspeisung Energiebedarf: \nAutarkie / Netzbezug \n30% \n70% \n39,00 Cent 25,53 Cent 0 ct 10 ct 20 ct 30 ct 40 ct 50 ct \nStromkosten in Cent pro Netzstro \nSolarstrom \n', 'next energy GmbH\nFeldstraße 4\n63636 Brachttal\n  Amtsgericht Hanau HRB 94661\nGeschäftsführer Torsten Eurich\nUSt-IdNr. DE293118835Raiffeisenbank Elsavatal\nBIC     GENODEF1EAU\nIBAN  DE27 7966 5540 0000 012955Telefon   06054 45735-0\neMail      kontakt@next-energy.info\nInternet  www.next-energy.info\nnachhaltige Energielösungen\nnext energy GmbH Feldstraße 4 63636 Brachttal\nHans Wener Weil\nBruchweg 7\n35410 HungenPatrick Jost\nTelefon 06054/45735-25\np.jost@next-energy.info\nAngebot Angebot Nr. AN2203862\nDatum 31.10.2022\nKunden Nr. 15877\nPos. Menge Bezeichnung Einzelpreis EUR Gesamtpreis EUR\n1 9,24 kWp Photovoltaikanlage\nzur Netzeinspeisung und Eigenverbrauch\nbestehend aus:\n- monokristallinen Solarmodulen\n- inkl. Wechselrichter mit 10 Jahren Garantie\n- inkl. Sunny Home Manager (Smart Meter)\n- inkl. WLAN/LAN Überwachungseinheit\n- inkl. Montagegestell\n- inkl. Absturzschutz (*)\n- inkl. Montage, Anmeldung, Inbetriebnahme\nund Dokumentation\n- inkl. An- und Abfahrt\nACHTUNG:\n(*) Zur Ausführung des Auftrags können Zusatz-\nkosten z.B. im Bereich des Zählerschranks\noder im Bereich Absturzschutz notwendig\nwerden. Dies wird jedoch vor Installation be-\nkannt gegeben.\nVor-Ort-Termine, die VOR einer schriftlichen\nBeauftragung gewünscht werden, berechnen\nwir mit 250,00 Euro zzgl. der derzeit gültigen\nMwSt. von 19%.\n2.150,00 19.866,00', 'next energy GmbH\nFeldstraße 4\n63636 Brachttal\n  Amtsgericht Hanau HRB 94661\nGeschäftsführer Torsten Eurich\nUSt-IdNr. DE293118835Raiffeisenbank Elsavatal\nBIC     GENODEF1EAU\nIBAN  DE27 7966 5540 0000 012955Telefon   06054 45735-0\neMail      kontakt@next-energy.info\nInternet  www.next-energy.info\n ...
