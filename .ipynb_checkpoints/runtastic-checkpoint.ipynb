# %% [markdown]
# # Runtastic data processing and visualisation

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import glob
import datetime
import seaborn as sns
import runtastic as rt

# %% [markdown]
# ## Process exported files

# %%
df = pd.DataFrame()
# fCount will contain the number of processed files
fCount = 0
for filepath in glob.iglob(r'./export-20210227-000/Sport-sessions/*.json'):
    fCount += 1
    if not df.empty:
        # if DataFrame already contains data, append the next dataset (= series)
        df = df.append([pd.read_json(filepath, typ='series')])
    else:
        # if DataFrame is still empty initialise it with the data from the first file being read
        df = pd.DataFrame([pd.read_json(filepath, typ='series')])

# %% [markdown]
# ## Optional: print out some basic figures about the imported data

# %%
print('Numbers of files processed: ' + str(fCount))
print('Dimensions of the DataFrame created: ' + str(df.shape))
print('Column name: ' + df.columns)
print(df.info())
print(df.head())
# Out:
# Numbers of files processed: 143
# Dimensions of the DataFrame created: (143, 43)
# Index(['Column name: start_time', 'Column name: end_time',
#        'Column name: created_at', 'Column name: updated_at',
#        'Column name: start_time_timezone_offset',
#        'Column name: end_time_timezone_offset', 'Column name: distance',
#        'Column name: duration', 'Column name: elevation_gain',
#        'Column name: elevation_loss', 'Column name: average_speed',
#        'Column name: calories', 'Column name: longitude',
#        'Column name: latitude', 'Column name: max_speed',
#        'Column name: pause_duration', 'Column name: duration_per_km',
#        'Column name: pulse_avg', 'Column name: pulse_max',
#        'Column name: max_step_frequency', 'Column name: avg_step_frequency',
#        'Column name: total_steps', 'Column name: manual',
#        'Column name: edited', 'Column name: completed',
#        'Column name: live_tracking_active',
#        'Column name: live_tracking_enabled', 'Column name: cheering_enabled',
#        'Column name: indoor', 'Column name: id', 'Column name: surface_id',
#        'Column name: subjective_feeling_id', 'Column name: sport_type_id',
#        'Column name: temperature', 'Column name: weather_condition_id',
#        'Column name: user_equipment_ids', 'Column name: fitness',
#        'Column name: training_plan', 'Column name: avg_cadence',
#        'Column name: max_cadence', 'Column name: notes',
#        'Column name: altitude_refined', 'Column name: route_id'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 143 entries, 0 to 0
# Data columns (total 43 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   start_time                  143 non-null    int64
#  1   end_time                    143 non-null    int64
#  2   created_at                  143 non-null    int64
#  3   updated_at                  143 non-null    int64
#  4   start_time_timezone_offset  143 non-null    int64
#  5   end_time_timezone_offset    143 non-null    int64
#  6   distance                    143 non-null    int64
#  7   duration                    143 non-null    int64
#  8   elevation_gain              136 non-null    float64
#  9   elevation_loss              136 non-null    float64
#  10  average_speed               136 non-null    float64
#  11  calories                    143 non-null    int64
#  12  longitude                   121 non-null    float64
#  13  latitude                    121 non-null    float64
#  14  max_speed                   136 non-null    float64
#  15  pause_duration              143 non-null    int64
#  16  duration_per_km             136 non-null    float64
#  17  pulse_avg                   106 non-null    float64
#  18  pulse_max                   106 non-null    float64
#  19  max_step_frequency          102 non-null    float64
#  20  avg_step_frequency          102 non-null    float64
#  21  total_steps                 102 non-null    float64
#  22  manual                      143 non-null    bool
#  23  edited                      136 non-null    object
#  24  completed                   143 non-null    bool
#  25  live_tracking_active        136 non-null    object
#  26  live_tracking_enabled       136 non-null    object
#  27  cheering_enabled            136 non-null    object
#  28  indoor                      136 non-null    object
#  29  id                          143 non-null    object
#  30  surface_id                  119 non-null    object
#  31  subjective_feeling_id       121 non-null    object
#  32  sport_type_id               143 non-null    object
#  33  temperature                 42 non-null     float64
#  34  weather_condition_id        46 non-null     object
#  35  user_equipment_ids          38 non-null     object
#  36  fitness                     7 non-null      object
#  37  training_plan               7 non-null      object
#  38  avg_cadence                 20 non-null     float64
#  39  max_cadence                 20 non-null     float64
#  40  notes                       3 non-null      object
#  41  altitude_refined            1 non-null      object
#  42  route_id                    1 non-null      object
# dtypes: bool(2), float64(15), int64(10), object(16)
# memory usage: 47.2+ KB
# None
#       start_time       end_time     created_at     updated_at  \
# 0  1610031869000  1610033535000  1610278840000  1610278841000
# 0  1601787775000  1601790174000  1601790203000  1601790715000
# 0  1606037110000  1606039145000  1606039731000  1606039732000
# 0  1590250719000  1590252436000  1590252454000  1590252454000
# 0  1597297637000  1597299536000  1597509732000  1597509732000
#
#    start_time_timezone_offset  end_time_timezone_offset  distance  duration  \
# 0                     3600000                   3600000      3701   1662086
# 0                     7200000                   7200000      4510   2399000
# 0                     3600000                   3600000      5416   2034992
# 0                     7200000                   7200000      4534   1716978
# 0                     7200000                   7200000      4726   1898991
#
#    elevation_gain  elevation_loss  ...  temperature  weather_condition_id  \
# 0            46.0            45.0  ...          NaN                   NaN
# 0             0.0             0.0  ...          NaN                   NaN
# 0           100.0           156.0  ...          NaN                   NaN
# 0            28.0            30.0  ...         16.0                     2
# 0           108.0           105.0  ...          NaN                   NaN
#
#            user_equipment_ids  fitness  training_plan  avg_cadence  \
# 0                         NaN      NaN            NaN          NaN
# 0                         NaN      NaN            NaN          NaN
# 0                         NaN      NaN            NaN          NaN
# 0  [5eaeec3e9076cb85890f5e40]      NaN            NaN          NaN
# 0                         NaN      NaN            NaN          NaN
#
#    max_cadence  notes  altitude_refined  route_id
# 0          NaN    NaN               NaN       NaN
# 0          NaN    NaN               NaN       NaN
# 0          NaN    NaN               NaN       NaN
# 0          NaN    NaN               NaN       NaN
# 0          NaN    NaN               NaN       NaN
#
# [5 rows x 43 columns]

# %% [markdown]
# ## Check for columns that have null/nan values so

# %%
print(df.isnull().sum())
# as a result, I neglect columns temperature, weather_condition_id, user_equipment_ids,
# fitness, training_plan, avg_cadence, max_cadence, notes, altitude_refined, route_id
# Out:
# start_time                      0
# end_time                        0
# created_at                      0
# updated_at                      0
# start_time_timezone_offset      0
# end_time_timezone_offset        0
# distance                        0
# duration                        0
# elevation_gain                  7
# elevation_loss                  7
# average_speed                   7
# calories                        0
# longitude                      22
# latitude                       22
# max_speed                       7
# pause_duration                  0
# duration_per_km                 7
# pulse_avg                      37
# pulse_max                      37
# max_step_frequency             41
# avg_step_frequency             41
# total_steps                    41
# manual                          0
# edited                          7
# completed                       0
# live_tracking_active            7
# live_tracking_enabled           7
# cheering_enabled                7
# indoor                          7
# id                              0
# surface_id                     24
# subjective_feeling_id          22
# sport_type_id                   0
# temperature                   101
# weather_condition_id           97
# user_equipment_ids            105
# fitness                       136
# training_plan                 136
# avg_cadence                   123
# max_cadence                   123
# notes                         140
# altitude_refined              142
# route_id                      142
# dtype: int64

# %% [markdown]
# ## create new DataFrame for further processing wo/several columns from the original

# %%
df_copy = df.copy()
df_copy = df_copy.drop(columns=['temperature', 'weather_condition_id', 'user_equipment_ids', 'fitness', 'training_plan', 'avg_cadence', 'max_cadence', 'notes', 'altitude_refined', 'route_id'])

# %%
print(df_copy.isnull().sum())
# Out:
# start_time                     0
# end_time                       0
# created_at                     0
# updated_at                     0
# start_time_timezone_offset     0
# end_time_timezone_offset       0
# distance                       0
# duration                       0
# elevation_gain                 7
# elevation_loss                 7
# average_speed                  7
# calories                       0
# longitude                     22
# latitude                      22
# max_speed                      7
# pause_duration                 0
# duration_per_km                7
# pulse_avg                     37
# pulse_max                     37
# max_step_frequency            41
# avg_step_frequency            41
# total_steps                   41
# manual                         0
# edited                         7
# completed                      0
# live_tracking_active           7
# live_tracking_enabled          7
# cheering_enabled               7
# indoor                         7
# id                             0
# surface_id                    24
# subjective_feeling_id         22
# sport_type_id                  0
# dtype: int64

# %% [markdown]
# ## add columns with humanly readable dates (converted from miliseconds)

# %%
# convert certain columns
# date: milliseconds to date
df_copy['start_date'] = pd.to_datetime(df_copy['start_time'], unit='ms')
df_copy['end_date'] = pd.to_datetime(df_copy['end_time'], unit='ms')
df_copy['year'] = df_copy['start_date'].dt.year
df_copy['month'] = df_copy['start_date'].dt.month

# %% [markdown]
# ## process categorical data and convert it to humanly readable values

# %%
# categorical data: surface_id, weather_condition_id, sport_type_id
activity_map = {'sport_type_id': {'1': 'Laufen', '3': 'Radfahren', '4': 'MTB', '14': 'Laufband', '18': 'Schwimmen', '19': 'Gehen', '64': '???'}}
surface_map = {'surface_id': {'1': 'Strasse', '2': 'Weg', '3': 'Gemischt', '4': 'Cross'}}
feeling_map = {'subjective_feeling_id': {'5': 'Gut', '2': 'So lala', '3': 'Fantastisch', '1': 'Schlecht', '4': 'Verletzt', '19': '', '64': ''}}
# replace the activity ids with readable values from the map
df_copy.replace(activity_map, inplace=True)
df_copy.replace(surface_map, inplace=True)
df_copy.replace(feeling_map, inplace=True)
# in Python, it's a good practice to typecase categorical features to a category type to fasten up the processing of the data
df_copy['sport_type_id'] = df_copy['sport_type_id'].astype('category')
df_copy['surface_id'] = df_copy['surface_id'].astype('category')
df_copy['subjective_feeling_id'] = df_copy['subjective_feeling_id'].astype('category')
activity_count = df_copy['sport_type_id'].value_counts()
sns.set(style="darkgrid")
sns.barplot(activity_count.index, activity_count.values, alpha=0.9)
plt.title('Frequency Distribution of Activities')
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Activity', fontsize=12)
plt.show()
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
print(df_copy.head())
df_test = df_copy.groupby(by=['year', 'sport_type_id'])['distance'].sum()
print(df_test.to_frame())
# Out:
#       start_time       end_time     created_at     updated_at  \
# 0  1610031869000  1610033535000  1610278840000  1610278841000
# 0  1601787775000  1601790174000  1601790203000  1601790715000
# 0  1606037110000  1606039145000  1606039731000  1606039732000
# 0  1590250719000  1590252436000  1590252454000  1590252454000
# 0  1597297637000  1597299536000  1597509732000  1597509732000
#
#    start_time_timezone_offset  end_time_timezone_offset  distance  duration  \
# 0                     3600000                   3600000      3701   1662086
# 0                     7200000                   7200000      4510   2399000
# 0                     3600000                   3600000      5416   2034992
# 0                     7200000                   7200000      4534   1716978
# 0                     7200000                   7200000      4726   1898991
#
#    elevation_gain  elevation_loss  ...  cheering_enabled  indoor  \
# 0            46.0            45.0  ...             False   False
# 0             0.0             0.0  ...             False   False
# 0           100.0           156.0  ...             False   False
# 0            28.0            30.0  ...             False   False
# 0           108.0           105.0  ...             False   False
#
#                                      id  surface_id  subjective_feeling_id  \
# 0  30994c8b-1b52-495d-afeb-07c5f5cfdec7         Weg                    Gut
# 0  5dc60305-4e96-4898-9e3e-537637c1d0ba     Strasse                    Gut
# 0  830ee323-aff9-4699-8cf7-6b736090ade0    Gemischt                So lala
# 0  30a0e348-3826-4845-9cdc-b399502f92a0         Weg                    Gut
# 0  786069da-3d6f-4e58-ac5d-aa8746dd7ab6    Gemischt                So lala
#
#    sport_type_id          start_date            end_date  year  month
# 0         Laufen 2021-01-07 15:04:29 2021-01-07 15:32:15  2021      1
# 0       Laufband 2020-10-04 05:02:55 2020-10-04 05:42:54  2020     10
# 0         Laufen 2020-11-22 09:25:10 2020-11-22 09:59:05  2020     11
# 0         Laufen 2020-05-23 16:18:39 2020-05-23 16:47:16  2020      5
# 0         Laufen 2020-08-13 05:47:17 2020-08-13 06:18:56  2020      8
#
# [5 rows x 37 columns]
#                     distance
# year sport_type_id
# 2014 ???                   0
#      Gehen              1503
#      Laufband              0
#      Laufen                0
#      MTB                   0
#      Radfahren             0
#      Schwimmen             0
# 2015 ???                   0
#      Gehen                 0
#      Laufband              0
#      Laufen                0
#      MTB                   0
#      Radfahren             0
#      Schwimmen             0
# 2016 ???                   0
#      Gehen              5200
#      Laufband              0
#      Laufen            11559
#      MTB                   0
#      Radfahren             0
#      Schwimmen             0
# 2017 ???                   0
#      Gehen                 0
#      Laufband              0
#      Laufen            48871
#      MTB              134488
#      Radfahren             0
#      Schwimmen             0
# 2018 ???                   0
#      Gehen                 0
#      Laufband              0
#      Laufen             4155
#      MTB                   0
#      Radfahren             0
#      Schwimmen             0
# 2020 ???                   0
#      Gehen             23526
#      Laufband          13580
#      Laufen           347475
#      MTB              125436
#      Radfahren         14475
#      Schwimmen           400
# 2021 ???                   0
#      Gehen                 0
#      Laufband              0
#      Laufen           116292
#      MTB                   0
#      Radfahren             0
#      Schwimmen             0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-1e50b36e322d> in <module>
#       2 df_test = df_copy.groupby(by=['year', 'sport_type_id'])['distance'].sum()
#       3 print(df_test.to_frame())
# ----> 4 print(df_test.to_frame()['year'])
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'year'

# %%
# first, create a list of labels for the diagram
labels = df_copy['year'].unique().tolist()
labels.sort()
# create lists per activity that contain the distances per year (dpy stands for distance per year)
# first create a filter...
running_filter = df_copy['sport_type_id'] == (activity_map['sport_type_id'])['1']
# which then is used to create a series of distances per year
df_running_dpy = df_copy.loc[running_filter, :].groupby(by=['year'])['distance'].sum()
# finally create a list of values
running_list = df_running_dpy.to_list()
# same for the other activities
walking_filter = df_copy['sport_type_id'] == (activity_map['sport_type_id'])['19']
df_walking_dpy = df_copy.loc[walking_filter, :].groupby(by=['year'])['distance'].sum()
swimming_filter = df_copy['sport_type_id'] == (activity_map['sport_type_id'])['18']
df_swimming_dpy = df_copy.loc[swimming_filter, :].groupby(by=['year'])['distance'].sum()
mtb_filter = df_copy['sport_type_id'] == (activity_map['sport_type_id'])['14']
df_mtb_dpy = df_copy.loc[mtb_filter, :].groupby(by=['year'])['distance'].sum()
mtb_list = df_mtb_dpy.to_list()
biking_filter = df_copy['sport_type_id'] == (activity_map['sport_type_id'])['3']
df_biking_dpy = df_copy.loc[biking_filter, :].groupby(by=['year'])['distance'].sum()
treadmill_filter = df_copy['sport_type_id'] == (activity_map['sport_type_id'])['18']
df_treadmill_dpy = df_copy.loc[treadmill_filter, :].groupby(by=['year'])['distance'].sum()

width = 0.35       # the width of the bars: can also be len(x) sequence
fig, ax = plt.subplots()

ax.bar([2017,2018,2019,2020, 2021], running_list, width, label='Run')
ax.bar([2017,2018,2019,2020, 2021], mtb_list, width, bottom=running_list, label='Mtb')

ax.set_ylabel('meters')
ax.set_title('Distances per year by activity type')
ax.legend()

plt.show()

# this is now a try to shorten the above process 
#df_dist_per_year = df_copy.groupby(by=['year', 'sport_type_id'])[['sport_type_id', 'year', 'distance']].sum(level='distance')
#running_filter2 = df_dist_per_year['sport_type_id'] == (activity_map['sport_type_id'])['1']

# means = [20, 35, 30, 35, 27]
# women_means = [25, 32, 34, 20, 25]
# men_std = [2, 3, 4, 1, 2]
# women_std = [3, 5, 2, 3, 3]

# %%
# then, get the unique values of activities
activities = df_copy['sport_type_id'].unique().tolist()
# Getting length of list
length = len(activities)
i = 0
# a dictionary t store keys and lists of values for the plot 
d = {}
# Iterating using while loop
while i < length:
    my_filter = df_copy['sport_type_id'] == activities[i]
    # d = {'<activity>' : [<list of summed up distances per activity and year]}
    d[activities[i]] = df_copy.loc[my_filter, :].groupby(by=['year'])['distance'].sum()
    print(activities[i])
    i += 1
# Out:
# Laufen
# Laufband
# ???
# MTB
# Schwimmen
# Gehen
# Radfahren

# %%
# use pandas Grouper to group data on a yearly base and sum distance up per year
df_dist_per_year = df_copy.groupby(['year'])[['distance']].sum()
df_dist_per_year['distance_km'] = df_dist_per_year/1000
df_dist_per_year
y_values = df_dist_per_year['distance_km']
x_values = df_dist_per_year.index
plt.barh(x_values, y_values)
plt.xlabel('Year')
plt.ylabel('Distance')
# Out:
# Text(0, 0.5, 'Distance')
