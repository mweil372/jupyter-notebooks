# %%
import sharepy
import requests
import json
import pandas as pd
import numpy as np
from jira import JIRA
import kmon

# %%
my_capa_parser = kmon.LocalCapaExcelFETL('FILE', pd.DataFrame)
my_capa_parser.load_data_source('./', 'CapaSheet2023.xlsm')
df = my_capa_parser.data_frame
my_capa_parser.print_status()
my_capa_parser.write_excel()
my_capa_parser.print_projects()
my_capa_parser.print_project_sum('DPM')
# Out:
# ./CapaSheet2023.xlsm
# Index([                               'k.management - Dashboard',
#                      'k.management - Dashboard Customer Support',
#                                                            'DPM',
#                                           'DPM Customer Support',
#                                     'PPS (STOLL) series support',
#                                        'PPS (STOLL) Development',
#                                                              nan,
#                                                    'KM.ON Cloud',
#                                              'KM.ON China Cloud',
#                                                'IAM & App Shell',
#                                         'k.ey - Device Software',
#                                 'k.ey - Device Customer Support',
#                                                              nan,
#                                                           'PDS ',
# ...
